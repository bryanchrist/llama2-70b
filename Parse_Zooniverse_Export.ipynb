# %% [markdown]
# ## Import Dependencies and Load in Data At Correct Index

# %%
import pandas as pd

# %%
df = pd.read_csv('Data/mathwell-mathematics-assessment-through-word-problems-extracted-from-large-language-models-classifications.csv')
df
# Out:
#       classification_id    user_name    user_id               user_ip  \
# 0             501808106  bryanchrist  2631956.0  401926a5b923b808f138
# 1             501808147  bryanchrist  2631956.0  401926a5b923b808f138
# 2             501808176  bryanchrist  2631956.0  401926a5b923b808f138
# 3             501808272  bryanchrist  2631956.0  401926a5b923b808f138
# 4             501809115  bryanchrist  2631956.0  401926a5b923b808f138
# ...                 ...          ...        ...                   ...
# 2146          520559305  bryanchrist  2631956.0  4c4964542f0ec3b2f658
# 2147          520559830  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2148          520559881  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2149          520559911  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2150          520559979  bryanchrist  2631956.0  a1476cbd89e0430d38e8
#
#       workflow_id       workflow_name  workflow_version  \
# 0           24740  Classify Questions            37.630
# 1           24740  Classify Questions            37.630
# 2           24740  Classify Questions            37.630
# 3           24740  Classify Questions            37.630
# 4           24740  Classify Questions            37.630
# ...           ...                 ...               ...
# 2146        24740  Classify Questions           114.169
# 2147        24740  Classify Questions           114.169
# 2148        24740  Classify Questions           114.169
# 2149        24740  Classify Questions           114.169
# 2150        24740  Classify Questions           114.169
#
#                    created_at  gold_standard  expert  \
# 0     2023-07-18 16:13:14 UTC            NaN     NaN
# 1     2023-07-18 16:13:27 UTC            NaN     NaN
# 2     2023-07-18 16:13:36 UTC            NaN     NaN
# 3     2023-07-18 16:14:12 UTC            NaN     NaN
# 4     2023-07-18 16:19:32 UTC            NaN     NaN
# ...                       ...            ...     ...
# 2146  2023-11-05 12:31:47 UTC            NaN     NaN
# 2147  2023-11-05 12:36:13 UTC            NaN     NaN
# 2148  2023-11-05 12:36:39 UTC            NaN     NaN
# 2149  2023-11-05 12:36:57 UTC            NaN     NaN
# 2150  2023-11-05 12:37:42 UTC            NaN     NaN
#
#                                                metadata  \
# 0     {"source":"api","session":"9a2534a2cdf37064e69...
# 1     {"source":"api","session":"9a2534a2cdf37064e69...
# 2     {"source":"api","session":"9a2534a2cdf37064e69...
# 3     {"source":"api","session":"9a2534a2cdf37064e69...
# 4     {"source":"api","session":"9a2534a2cdf37064e69...
# ...                                                 ...
# 2146  {"source":"api","session":"10620789f6003517ace...
# 2147  {"source":"api","session":"10620789f6003517ace...
# 2148  {"source":"api","session":"10620789f6003517ace...
# 2149  {"source":"api","session":"10620789f6003517ace...
# 2150  {"source":"api","session":"10620789f6003517ace...
#
#                                             annotations  \
# 0     [{"task":"T0","task_label":"Is this question s...
# 1     [{"task":"T0","task_label":"Is this question s...
# 2     [{"task":"T0","task_label":"Is this question s...
# 3     [{"task":"T0","task_label":"Is this question s...
# 4     [{"task":"T0","task_label":"Is this question s...
# ...                                                 ...
# 2146  [{"task":"T0","task_label":"Is this question s...
# 2147  [{"task":"T0","task_label":"Is this question s...
# 2148  [{"task":"T0","task_label":"Is this question s...
# 2149  [{"task":"T0","task_label":"Is this question s...
# 2150  [{"task":"T0","task_label":"Is this question s...
#
#                                            subject_data  subject_ids
# 0     {"90771026":{"retired":null,"Filename":"questi...     90771026
# 1     {"90771026":{"retired":null,"Filename":"questi...     90771026
# 2     {"90771026":{"retired":null,"Filename":"questi...     90771026
# 3     {"90771026":{"retired":null,"Filename":"questi...     90771026
# 4     {"90771026":{"retired":null,"Filename":"questi...     90771026
# ...                                                 ...          ...
# 2146  {"92651524":{"retired":null,"Filename":"questi...     92651524
# 2147  {"92650875":{"retired":null,"Filename":"questi...     92650875
# 2148  {"92653994":{"retired":null,"Filename":"questi...     92653994
# 2149  {"92653416":{"retired":null,"Filename":"questi...     92653416
# 2150  {"92651390":{"retired":null,"Filename":"questi...     92651390
#
# [2151 rows x 14 columns]

# %%
start_index = 166
df = df[start_index:]
df
# Out:
#       classification_id    user_name    user_id               user_ip  \
# 166           518580047  bryanchrist  2631956.0  6bbf22d89d31f02b8581
# 167           518580331  bryanchrist  2631956.0  6bbf22d89d31f02b8581
# 168           518580963  bryanchrist  2631956.0  0f5b485177bfa88563b9
# 169           518581032  bryanchrist  2631956.0  0f5b485177bfa88563b9
# 170           518581136  bryanchrist  2631956.0  0f5b485177bfa88563b9
# ...                 ...          ...        ...                   ...
# 2146          520559305  bryanchrist  2631956.0  4c4964542f0ec3b2f658
# 2147          520559830  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2148          520559881  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2149          520559911  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2150          520559979  bryanchrist  2631956.0  a1476cbd89e0430d38e8
#
#       workflow_id       workflow_name  workflow_version  \
# 166         24740  Classify Questions           114.169
# 167         24740  Classify Questions           114.169
# 168         24740  Classify Questions           114.169
# 169         24740  Classify Questions           114.169
# 170         24740  Classify Questions           114.169
# ...           ...                 ...               ...
# 2146        24740  Classify Questions           114.169
# 2147        24740  Classify Questions           114.169
# 2148        24740  Classify Questions           114.169
# 2149        24740  Classify Questions           114.169
# 2150        24740  Classify Questions           114.169
#
#                    created_at  gold_standard  expert  \
# 166   2023-10-26 15:44:26 UTC            NaN     NaN
# 167   2023-10-26 15:45:16 UTC            NaN     NaN
# 168   2023-10-26 15:46:58 UTC            NaN     NaN
# 169   2023-10-26 15:47:10 UTC            NaN     NaN
# 170   2023-10-26 15:47:26 UTC            NaN     NaN
# ...                       ...            ...     ...
# 2146  2023-11-05 12:31:47 UTC            NaN     NaN
# 2147  2023-11-05 12:36:13 UTC            NaN     NaN
# 2148  2023-11-05 12:36:39 UTC            NaN     NaN
# 2149  2023-11-05 12:36:57 UTC            NaN     NaN
# 2150  2023-11-05 12:37:42 UTC            NaN     NaN
#
#                                                metadata  \
# 166   {"source":"api","session":"0588d55084272e4128a...
# 167   {"source":"api","session":"0588d55084272e4128a...
# 168   {"source":"api","session":"0588d55084272e4128a...
# 169   {"source":"api","session":"0588d55084272e4128a...
# 170   {"source":"api","session":"0588d55084272e4128a...
# ...                                                 ...
# 2146  {"source":"api","session":"10620789f6003517ace...
# 2147  {"source":"api","session":"10620789f6003517ace...
# 2148  {"source":"api","session":"10620789f6003517ace...
# 2149  {"source":"api","session":"10620789f6003517ace...
# 2150  {"source":"api","session":"10620789f6003517ace...
#
#                                             annotations  \
# 166   [{"task":"T0","task_label":"Is this question s...
# 167   [{"task":"T0","task_label":"Is this question s...
# 168   [{"task":"T0","task_label":"Is this question s...
# 169   [{"task":"T0","task_label":"Is this question s...
# 170   [{"task":"T0","task_label":"Is this question s...
# ...                                                 ...
# 2146  [{"task":"T0","task_label":"Is this question s...
# 2147  [{"task":"T0","task_label":"Is this question s...
# 2148  [{"task":"T0","task_label":"Is this question s...
# 2149  [{"task":"T0","task_label":"Is this question s...
# 2150  [{"task":"T0","task_label":"Is this question s...
#
#                                            subject_data  subject_ids
# 166   {"92652275":{"retired":null,"Filename":"questi...     92652275
# 167   {"92650744":{"retired":null,"Filename":"questi...     92650744
# 168   {"92651965":{"retired":null,"Filename":"questi...     92651965
# 169   {"92654071":{"retired":null,"Filename":"questi...     92654071
# 170   {"92650910":{"retired":null,"Filename":"questi...     92650910
# ...                                                 ...          ...
# 2146  {"92651524":{"retired":null,"Filename":"questi...     92651524
# 2147  {"92650875":{"retired":null,"Filename":"questi...     92650875
# 2148  {"92653994":{"retired":null,"Filename":"questi...     92653994
# 2149  {"92653416":{"retired":null,"Filename":"questi...     92653416
# 2150  {"92651390":{"retired":null,"Filename":"questi...     92651390
#
# [1985 rows x 14 columns]

# %% [markdown]
# ## Create Appropriateness, Solvability, Accuracy, and Notes Columns

# %%
import json
solvability = []
accuracy = []
appropriateness = []
notes = []
for i in range(0, len(df)):
    my_json = json.loads(df.iloc[i]['annotations'])
    solvability.append(my_json[0]['value'])
    if my_json[1]['task']=='T4':
        accuracy.append(my_json[1]['value'])
    if my_json[1]['task']!='T4':
        accuracy.append("NA")
        appropriateness.append(my_json[1]['value'])
    if my_json[2]['task']=='T1':
        appropriateness.append(my_json[2]['value'])
    if my_json[2]['task']!='T1':
        notes.append(my_json[2]['value'])
    try:
        notes.append(my_json[3]['value'])
    except:
        pass
df['solvability']=solvability
df['appropriateness']=appropriateness
df['accuracy']=accuracy
df['notes']=notes
# Out:
# <ipython-input-4-b75638aa5026>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['solvability']=solvability
# <ipython-input-4-b75638aa5026>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['appropriateness']=appropriateness
# <ipython-input-4-b75638aa5026>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['accuracy']=accuracy
# <ipython-input-4-b75638aa5026>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['notes']=notes

# %%
df
# Out:
#       classification_id    user_name    user_id               user_ip  \
# 166           518580047  bryanchrist  2631956.0  6bbf22d89d31f02b8581
# 167           518580331  bryanchrist  2631956.0  6bbf22d89d31f02b8581
# 168           518580963  bryanchrist  2631956.0  0f5b485177bfa88563b9
# 169           518581032  bryanchrist  2631956.0  0f5b485177bfa88563b9
# 170           518581136  bryanchrist  2631956.0  0f5b485177bfa88563b9
# ...                 ...          ...        ...                   ...
# 2146          520559305  bryanchrist  2631956.0  4c4964542f0ec3b2f658
# 2147          520559830  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2148          520559881  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2149          520559911  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2150          520559979  bryanchrist  2631956.0  a1476cbd89e0430d38e8
#
#       workflow_id       workflow_name  workflow_version  \
# 166         24740  Classify Questions           114.169
# 167         24740  Classify Questions           114.169
# 168         24740  Classify Questions           114.169
# 169         24740  Classify Questions           114.169
# 170         24740  Classify Questions           114.169
# ...           ...                 ...               ...
# 2146        24740  Classify Questions           114.169
# 2147        24740  Classify Questions           114.169
# 2148        24740  Classify Questions           114.169
# 2149        24740  Classify Questions           114.169
# 2150        24740  Classify Questions           114.169
#
#                    created_at  gold_standard  expert  \
# 166   2023-10-26 15:44:26 UTC            NaN     NaN
# 167   2023-10-26 15:45:16 UTC            NaN     NaN
# 168   2023-10-26 15:46:58 UTC            NaN     NaN
# 169   2023-10-26 15:47:10 UTC            NaN     NaN
# 170   2023-10-26 15:47:26 UTC            NaN     NaN
# ...                       ...            ...     ...
# 2146  2023-11-05 12:31:47 UTC            NaN     NaN
# 2147  2023-11-05 12:36:13 UTC            NaN     NaN
# 2148  2023-11-05 12:36:39 UTC            NaN     NaN
# 2149  2023-11-05 12:36:57 UTC            NaN     NaN
# 2150  2023-11-05 12:37:42 UTC            NaN     NaN
#
#                                                metadata  \
# 166   {"source":"api","session":"0588d55084272e4128a...
# 167   {"source":"api","session":"0588d55084272e4128a...
# 168   {"source":"api","session":"0588d55084272e4128a...
# 169   {"source":"api","session":"0588d55084272e4128a...
# 170   {"source":"api","session":"0588d55084272e4128a...
# ...                                                 ...
# 2146  {"source":"api","session":"10620789f6003517ace...
# 2147  {"source":"api","session":"10620789f6003517ace...
# 2148  {"source":"api","session":"10620789f6003517ace...
# 2149  {"source":"api","session":"10620789f6003517ace...
# 2150  {"source":"api","session":"10620789f6003517ace...
#
#                                             annotations  \
# 166   [{"task":"T0","task_label":"Is this question s...
# 167   [{"task":"T0","task_label":"Is this question s...
# 168   [{"task":"T0","task_label":"Is this question s...
# 169   [{"task":"T0","task_label":"Is this question s...
# 170   [{"task":"T0","task_label":"Is this question s...
# ...                                                 ...
# 2146  [{"task":"T0","task_label":"Is this question s...
# 2147  [{"task":"T0","task_label":"Is this question s...
# 2148  [{"task":"T0","task_label":"Is this question s...
# 2149  [{"task":"T0","task_label":"Is this question s...
# 2150  [{"task":"T0","task_label":"Is this question s...
#
#                                            subject_data  subject_ids  \
# 166   {"92652275":{"retired":null,"Filename":"questi...     92652275
# 167   {"92650744":{"retired":null,"Filename":"questi...     92650744
# 168   {"92651965":{"retired":null,"Filename":"questi...     92651965
# 169   {"92654071":{"retired":null,"Filename":"questi...     92654071
# 170   {"92650910":{"retired":null,"Filename":"questi...     92650910
# ...                                                 ...          ...
# 2146  {"92651524":{"retired":null,"Filename":"questi...     92651524
# 2147  {"92650875":{"retired":null,"Filename":"questi...     92650875
# 2148  {"92653994":{"retired":null,"Filename":"questi...     92653994
# 2149  {"92653416":{"retired":null,"Filename":"questi...     92653416
# 2150  {"92651390":{"retired":null,"Filename":"questi...     92651390
#
#      solvability                                    appropriateness accuracy  \
# 166          Yes  Yes: This question is understandable, appropri...      Yes
# 167          Yes  No: The question is too hard, even for a middl...       No
# 168          Yes  No: This question is strange, confusing, conta...      Yes
# 169          Yes  Yes: This question is understandable, appropri...      Yes
# 170           No  No: This question is strange, confusing, conta...       NA
# ...          ...                                                ...      ...
# 2146         Yes  Yes: This question is understandable, appropri...      Yes
# 2147         Yes  No: This question is strange, confusing, conta...      Yes
# 2148          No  No: This question is strange, confusing, conta...       NA
# 2149         Yes  Yes: This question is understandable, appropri...      Yes
# 2150         Yes  No: This question is strange, confusing, conta...      Yes
#
#      notes
# 166
# 167
# 168
# 169
# 170
# ...    ...
# 2146
# 2147
# 2148
# 2149
# 2150
#
# [1985 rows x 18 columns]

# %% [markdown]
# ## Look at Initial Statistics

# %%
df['appropriateness'].value_counts()
# Out:
# Yes: This question is understandable, appropriate and a middle school student or younger could solve it      1455
# No: This question is strange, confusing, contains conflicting information, and/or is not based in reality     432
# No: This question contains inappropriate material                                                              40
# No: This question contains distracting typos or grammatical errors                                             35
# No: The question is too hard, even for a middle school student                                                 23
# Name: appropriateness, dtype: int64

# %%
df['accuracy'].value_counts()
# Out:
# Yes    1542
# NA      244
# No      199
# Name: accuracy, dtype: int64

# %%
df['solvability'].value_counts()
# Out:
# Yes    1741
# No      244
# Name: solvability, dtype: int64

# %%
temp = df[df['notes']!=""]
temp
# Out:
#       classification_id                           user_name    user_id  \
# 186           518709509  not-logged-in-a37966e36cc5dda457a0        NaN
# 190           518710516  not-logged-in-00a6e25e48bf5304e5da        NaN
# 204           518734315  not-logged-in-c569a3df9a17a44dfe1b        NaN
# 205           518734316  not-logged-in-c569a3df9a17a44dfe1b        NaN
# 208           518734491  not-logged-in-c569a3df9a17a44dfe1b        NaN
# ...                 ...                                 ...        ...
# 2127          520550169                           kidleader  2668795.0
# 2128          520550408                           kidleader  2668795.0
# 2130          520550753                           kidleader  2668795.0
# 2134          520551293                           kidleader  2668795.0
# 2136          520551433                           kidleader  2668795.0
#
#                    user_ip  workflow_id       workflow_name  workflow_version  \
# 186   a37966e36cc5dda457a0        24740  Classify Questions           114.169
# 190   00a6e25e48bf5304e5da        24740  Classify Questions           114.169
# 204   c569a3df9a17a44dfe1b        24740  Classify Questions           114.169
# 205   c569a3df9a17a44dfe1b        24740  Classify Questions           114.169
# 208   c569a3df9a17a44dfe1b        24740  Classify Questions           114.169
# ...                    ...          ...                 ...               ...
# 2127  edbf3f62367914477597        24740  Classify Questions           114.169
# 2128  abe6fa9320f0ac5be905        24740  Classify Questions           114.169
# 2130  42a0a4c33553fc83ace9        24740  Classify Questions           114.169
# 2134  f660d68557d025e537c0        24740  Classify Questions           114.169
# 2136  f660d68557d025e537c0        24740  Classify Questions           114.169
#
#                    created_at  gold_standard  expert  \
# 186   2023-10-26 21:34:44 UTC            NaN     NaN
# 190   2023-10-26 21:39:36 UTC            NaN     NaN
# 204   2023-10-27 00:31:47 UTC            NaN     NaN
# 205   2023-10-27 00:31:47 UTC            NaN     NaN
# 208   2023-10-27 00:33:06 UTC            NaN     NaN
# ...                       ...            ...     ...
# 2127  2023-11-05 10:47:24 UTC            NaN     NaN
# 2128  2023-11-05 10:50:23 UTC            NaN     NaN
# 2130  2023-11-05 10:54:20 UTC            NaN     NaN
# 2134  2023-11-05 10:59:03 UTC            NaN     NaN
# 2136  2023-11-05 11:00:10 UTC            NaN     NaN
#
#                                                metadata  \
# 186   {"source":"api","session":"cab4af948923ae20b20...
# 190   {"source":"api","session":"cab4af948923ae20b20...
# 204   {"source":"api","session":"cab4af948923ae20b20...
# 205   {"source":"api","session":"cab4af948923ae20b20...
# 208   {"source":"api","session":"cab4af948923ae20b20...
# ...                                                 ...
# 2127  {"source":"api","session":"7501932d62eb7243f25...
# 2128  {"source":"api","session":"7501932d62eb7243f25...
# 2130  {"source":"api","session":"7501932d62eb7243f25...
# 2134  {"source":"api","session":"7501932d62eb7243f25...
# 2136  {"source":"api","session":"7501932d62eb7243f25...
#
#                                             annotations  \
# 186   [{"task":"T0","task_label":"Is this question s...
# 190   [{"task":"T0","task_label":"Is this question s...
# 204   [{"task":"T0","task_label":"Is this question s...
# 205   [{"task":"T0","task_label":"Is this question s...
# 208   [{"task":"T0","task_label":"Is this question s...
# ...                                                 ...
# 2127  [{"task":"T0","task_label":"Is this question s...
# 2128  [{"task":"T0","task_label":"Is this question s...
# 2130  [{"task":"T0","task_label":"Is this question s...
# 2134  [{"task":"T0","task_label":"Is this question s...
# 2136  [{"task":"T0","task_label":"Is this question s...
#
#                                            subject_data  subject_ids  \
# 186   {"92653922":{"retired":null,"Filename":"questi...     92653922
# 190   {"92650739":{"retired":null,"Filename":"questi...     92650739
# 204   {"92652322":{"retired":null,"Filename":"questi...     92652322
# 205   {"92653257":{"retired":null,"Filename":"questi...     92653257
# 208   {"92651009":{"retired":null,"Filename":"questi...     92651009
# ...                                                 ...          ...
# 2127  {"92651564":{"retired":null,"Filename":"questi...     92651564
# 2128  {"92654284":{"retired":null,"Filename":"questi...     92654284
# 2130  {"92654270":{"retired":null,"Filename":"questi...     92654270
# 2134  {"92651870":{"retired":null,"Filename":"questi...     92651870
# 2136  {"92652316":{"retired":null,"Filename":"questi...     92652316
#
#      solvability                                    appropriateness accuracy  \
# 186          Yes  Yes: This question is understandable, appropri...      Yes
# 190           No  No: This question is strange, confusing, conta...       NA
# 204           No  No: This question is strange, confusing, conta...       NA
# 205           No  No: This question is strange, confusing, conta...       NA
# 208          Yes  Yes: This question is understandable, appropri...      Yes
# ...          ...                                                ...      ...
# 2127         Yes  Yes: This question is understandable, appropri...       No
# 2128         Yes  Yes: This question is understandable, appropri...       No
# 2130         Yes  Yes: This question is understandable, appropri...       No
# 2134          No  No: This question is strange, confusing, conta...       NA
# 2136          No  No: This question is strange, confusing, conta...       NA
#
#                                                   notes
# 186                  Very niche knowledge of volleyball
# 190   Diet is not the right word. There is also no o...
# 204                    We can’t have negative icecreams
# 205   Here- horse power is measure in multiples comp...
# 208             This could be seen as a trick question…
# ...                                                 ...
# 2127  12:10 + 20 min. = 12:30 pm. 12:30 + 15 min. = ...
# 2128    525 - 110 - 211 - 66 = 138 students in neither.
# 2130  More information is required for the answer to...
# 2134  I'm not familiar enough with Instagram to unde...
# 2136                  I already surveyed this question.
#
# [153 rows x 18 columns]

# %% [markdown]
# ## Assign Question Numbers

# %%
question_numbers = []
for i in range(0, len(df)):
    my_json = json.loads(df.iloc[i]['subject_data'])
    subject_id = df.iloc[i]['subject_ids']
    question_number = my_json[f'{subject_id}']['Filename']
    question_number = question_number.split(".txt")[0]
    question_numbers.append(question_number)
df['question_number']=question_numbers
# Out:
# <ipython-input-10-6fbe7029c2dd>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['question_number']=question_numbers

# %%
df
# Out:
#       classification_id    user_name    user_id               user_ip  \
# 166           518580047  bryanchrist  2631956.0  6bbf22d89d31f02b8581
# 167           518580331  bryanchrist  2631956.0  6bbf22d89d31f02b8581
# 168           518580963  bryanchrist  2631956.0  0f5b485177bfa88563b9
# 169           518581032  bryanchrist  2631956.0  0f5b485177bfa88563b9
# 170           518581136  bryanchrist  2631956.0  0f5b485177bfa88563b9
# ...                 ...          ...        ...                   ...
# 2146          520559305  bryanchrist  2631956.0  4c4964542f0ec3b2f658
# 2147          520559830  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2148          520559881  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2149          520559911  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2150          520559979  bryanchrist  2631956.0  a1476cbd89e0430d38e8
#
#       workflow_id       workflow_name  workflow_version  \
# 166         24740  Classify Questions           114.169
# 167         24740  Classify Questions           114.169
# 168         24740  Classify Questions           114.169
# 169         24740  Classify Questions           114.169
# 170         24740  Classify Questions           114.169
# ...           ...                 ...               ...
# 2146        24740  Classify Questions           114.169
# 2147        24740  Classify Questions           114.169
# 2148        24740  Classify Questions           114.169
# 2149        24740  Classify Questions           114.169
# 2150        24740  Classify Questions           114.169
#
#                    created_at  gold_standard  expert  \
# 166   2023-10-26 15:44:26 UTC            NaN     NaN
# 167   2023-10-26 15:45:16 UTC            NaN     NaN
# 168   2023-10-26 15:46:58 UTC            NaN     NaN
# 169   2023-10-26 15:47:10 UTC            NaN     NaN
# 170   2023-10-26 15:47:26 UTC            NaN     NaN
# ...                       ...            ...     ...
# 2146  2023-11-05 12:31:47 UTC            NaN     NaN
# 2147  2023-11-05 12:36:13 UTC            NaN     NaN
# 2148  2023-11-05 12:36:39 UTC            NaN     NaN
# 2149  2023-11-05 12:36:57 UTC            NaN     NaN
# 2150  2023-11-05 12:37:42 UTC            NaN     NaN
#
#                                                metadata  \
# 166   {"source":"api","session":"0588d55084272e4128a...
# 167   {"source":"api","session":"0588d55084272e4128a...
# 168   {"source":"api","session":"0588d55084272e4128a...
# 169   {"source":"api","session":"0588d55084272e4128a...
# 170   {"source":"api","session":"0588d55084272e4128a...
# ...                                                 ...
# 2146  {"source":"api","session":"10620789f6003517ace...
# 2147  {"source":"api","session":"10620789f6003517ace...
# 2148  {"source":"api","session":"10620789f6003517ace...
# 2149  {"source":"api","session":"10620789f6003517ace...
# 2150  {"source":"api","session":"10620789f6003517ace...
#
#                                             annotations  \
# 166   [{"task":"T0","task_label":"Is this question s...
# 167   [{"task":"T0","task_label":"Is this question s...
# 168   [{"task":"T0","task_label":"Is this question s...
# 169   [{"task":"T0","task_label":"Is this question s...
# 170   [{"task":"T0","task_label":"Is this question s...
# ...                                                 ...
# 2146  [{"task":"T0","task_label":"Is this question s...
# 2147  [{"task":"T0","task_label":"Is this question s...
# 2148  [{"task":"T0","task_label":"Is this question s...
# 2149  [{"task":"T0","task_label":"Is this question s...
# 2150  [{"task":"T0","task_label":"Is this question s...
#
#                                            subject_data  subject_ids  \
# 166   {"92652275":{"retired":null,"Filename":"questi...     92652275
# 167   {"92650744":{"retired":null,"Filename":"questi...     92650744
# 168   {"92651965":{"retired":null,"Filename":"questi...     92651965
# 169   {"92654071":{"retired":null,"Filename":"questi...     92654071
# 170   {"92650910":{"retired":null,"Filename":"questi...     92650910
# ...                                                 ...          ...
# 2146  {"92651524":{"retired":null,"Filename":"questi...     92651524
# 2147  {"92650875":{"retired":null,"Filename":"questi...     92650875
# 2148  {"92653994":{"retired":null,"Filename":"questi...     92653994
# 2149  {"92653416":{"retired":null,"Filename":"questi...     92653416
# 2150  {"92651390":{"retired":null,"Filename":"questi...     92651390
#
#      solvability                                    appropriateness accuracy  \
# 166          Yes  Yes: This question is understandable, appropri...      Yes
# 167          Yes  No: The question is too hard, even for a middl...       No
# 168          Yes  No: This question is strange, confusing, conta...      Yes
# 169          Yes  Yes: This question is understandable, appropri...      Yes
# 170           No  No: This question is strange, confusing, conta...       NA
# ...          ...                                                ...      ...
# 2146         Yes  Yes: This question is understandable, appropri...      Yes
# 2147         Yes  No: This question is strange, confusing, conta...      Yes
# 2148          No  No: This question is strange, confusing, conta...       NA
# 2149         Yes  Yes: This question is understandable, appropri...      Yes
# 2150         Yes  No: This question is strange, confusing, conta...      Yes
#
#      notes question_number
# 166          question_1521
# 167           question_279
# 168          question_1266
# 169          question_2923
# 170           question_414
# ...    ...             ...
# 2146          question_913
# 2147          question_385
# 2148         question_2859
# 2149         question_2430
# 2150          question_807
#
# [1985 rows x 19 columns]

# %%
import numpy as np
replace_map = {"Yes": 1, "No": 0, "NA": np.nan}
df['solvability'] = df['solvability'].replace(replace_map)
df['accuracy'] = df['accuracy'].replace(replace_map)
replace_map = {"Yes: This question is understandable, appropriate and a middle school student or younger could solve it ": 1, 
               "No: This question is strange, confusing, contains conflicting information, and/or is not based in reality": 0, 
               "No: This question contains distracting typos or grammatical errors": 0, 
               "No: This question contains inappropriate material": 0, 
              "No: The question is too hard, even for a middle school student": 0}
df['appropriateness'] = df['appropriateness'].replace(replace_map)
# Out:
# <ipython-input-12-eedc2057c577>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['solvability'] = df['solvability'].replace(replace_map)
# <ipython-input-12-eedc2057c577>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['accuracy'] = df['accuracy'].replace(replace_map)
# <ipython-input-12-eedc2057c577>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['appropriateness'] = df['appropriateness'].replace(replace_map)

# %%
df
# Out:
#       classification_id    user_name    user_id               user_ip  \
# 166           518580047  bryanchrist  2631956.0  6bbf22d89d31f02b8581
# 167           518580331  bryanchrist  2631956.0  6bbf22d89d31f02b8581
# 168           518580963  bryanchrist  2631956.0  0f5b485177bfa88563b9
# 169           518581032  bryanchrist  2631956.0  0f5b485177bfa88563b9
# 170           518581136  bryanchrist  2631956.0  0f5b485177bfa88563b9
# ...                 ...          ...        ...                   ...
# 2146          520559305  bryanchrist  2631956.0  4c4964542f0ec3b2f658
# 2147          520559830  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2148          520559881  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2149          520559911  bryanchrist  2631956.0  a1476cbd89e0430d38e8
# 2150          520559979  bryanchrist  2631956.0  a1476cbd89e0430d38e8
#
#       workflow_id       workflow_name  workflow_version  \
# 166         24740  Classify Questions           114.169
# 167         24740  Classify Questions           114.169
# 168         24740  Classify Questions           114.169
# 169         24740  Classify Questions           114.169
# 170         24740  Classify Questions           114.169
# ...           ...                 ...               ...
# 2146        24740  Classify Questions           114.169
# 2147        24740  Classify Questions           114.169
# 2148        24740  Classify Questions           114.169
# 2149        24740  Classify Questions           114.169
# 2150        24740  Classify Questions           114.169
#
#                    created_at  gold_standard  expert  \
# 166   2023-10-26 15:44:26 UTC            NaN     NaN
# 167   2023-10-26 15:45:16 UTC            NaN     NaN
# 168   2023-10-26 15:46:58 UTC            NaN     NaN
# 169   2023-10-26 15:47:10 UTC            NaN     NaN
# 170   2023-10-26 15:47:26 UTC            NaN     NaN
# ...                       ...            ...     ...
# 2146  2023-11-05 12:31:47 UTC            NaN     NaN
# 2147  2023-11-05 12:36:13 UTC            NaN     NaN
# 2148  2023-11-05 12:36:39 UTC            NaN     NaN
# 2149  2023-11-05 12:36:57 UTC            NaN     NaN
# 2150  2023-11-05 12:37:42 UTC            NaN     NaN
#
#                                                metadata  \
# 166   {"source":"api","session":"0588d55084272e4128a...
# 167   {"source":"api","session":"0588d55084272e4128a...
# 168   {"source":"api","session":"0588d55084272e4128a...
# 169   {"source":"api","session":"0588d55084272e4128a...
# 170   {"source":"api","session":"0588d55084272e4128a...
# ...                                                 ...
# 2146  {"source":"api","session":"10620789f6003517ace...
# 2147  {"source":"api","session":"10620789f6003517ace...
# 2148  {"source":"api","session":"10620789f6003517ace...
# 2149  {"source":"api","session":"10620789f6003517ace...
# 2150  {"source":"api","session":"10620789f6003517ace...
#
#                                             annotations  \
# 166   [{"task":"T0","task_label":"Is this question s...
# 167   [{"task":"T0","task_label":"Is this question s...
# 168   [{"task":"T0","task_label":"Is this question s...
# 169   [{"task":"T0","task_label":"Is this question s...
# 170   [{"task":"T0","task_label":"Is this question s...
# ...                                                 ...
# 2146  [{"task":"T0","task_label":"Is this question s...
# 2147  [{"task":"T0","task_label":"Is this question s...
# 2148  [{"task":"T0","task_label":"Is this question s...
# 2149  [{"task":"T0","task_label":"Is this question s...
# 2150  [{"task":"T0","task_label":"Is this question s...
#
#                                            subject_data  subject_ids  \
# 166   {"92652275":{"retired":null,"Filename":"questi...     92652275
# 167   {"92650744":{"retired":null,"Filename":"questi...     92650744
# 168   {"92651965":{"retired":null,"Filename":"questi...     92651965
# 169   {"92654071":{"retired":null,"Filename":"questi...     92654071
# 170   {"92650910":{"retired":null,"Filename":"questi...     92650910
# ...                                                 ...          ...
# 2146  {"92651524":{"retired":null,"Filename":"questi...     92651524
# 2147  {"92650875":{"retired":null,"Filename":"questi...     92650875
# 2148  {"92653994":{"retired":null,"Filename":"questi...     92653994
# 2149  {"92653416":{"retired":null,"Filename":"questi...     92653416
# 2150  {"92651390":{"retired":null,"Filename":"questi...     92651390
#
#       solvability  appropriateness  accuracy notes question_number
# 166             1                1       1.0         question_1521
# 167             1                0       0.0          question_279
# 168             1                0       1.0         question_1266
# 169             1                1       1.0         question_2923
# 170             0                0       NaN          question_414
# ...           ...              ...       ...   ...             ...
# 2146            1                1       1.0          question_913
# 2147            1                0       1.0          question_385
# 2148            0                0       NaN         question_2859
# 2149            1                1       1.0         question_2430
# 2150            1                0       1.0          question_807
#
# [1985 rows x 19 columns]

# %% [markdown]
# ## Retain Necessary Columns and Aggregate Ratings

# %%
df = df[['user_name','question_number', 'solvability', 'accuracy', 'appropriateness', 'notes']]

# %%
# 1. Group by question and calculate the average score
df['average_solvability'] = df.groupby('question_number')['solvability'].transform('mean')
df['average_accuracy'] = df.groupby('question_number')['accuracy'].transform('mean')
df['average_appropriateness']=df.groupby('question_number')['appropriateness'].transform('mean')
# Out:
# <ipython-input-15-a4e0bc7177f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['average_solvability'] = df.groupby('question_number')['solvability'].transform('mean')
# <ipython-input-15-a4e0bc7177f0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['average_accuracy'] = df.groupby('question_number')['accuracy'].transform('mean')
# <ipython-input-15-a4e0bc7177f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['average_appropriateness']=df.groupby('question_number')['appropriateness'].transform('mean')

# %%
df
# Out:
#         user_name question_number  solvability  accuracy  appropriateness  \
# 166   bryanchrist   question_1521            1       1.0                1
# 167   bryanchrist    question_279            1       0.0                0
# 168   bryanchrist   question_1266            1       1.0                0
# 169   bryanchrist   question_2923            1       1.0                1
# 170   bryanchrist    question_414            0       NaN                0
# ...           ...             ...          ...       ...              ...
# 2146  bryanchrist    question_913            1       1.0                1
# 2147  bryanchrist    question_385            1       1.0                0
# 2148  bryanchrist   question_2859            0       NaN                0
# 2149  bryanchrist   question_2430            1       1.0                1
# 2150  bryanchrist    question_807            1       1.0                0
#
#      notes  average_solvability  average_accuracy  average_appropriateness
# 166                         1.0               1.0                      1.0
# 167                         1.0               0.0                      0.5
# 168                         1.0               1.0                      0.0
# 169                         1.0               1.0                      1.0
# 170                         0.0               NaN                      0.0
# ...    ...                  ...               ...                      ...
# 2146                        1.0               1.0                      1.0
# 2147                        1.0               1.0                      0.0
# 2148                        0.0               NaN                      0.0
# 2149                        1.0               1.0                      1.0
# 2150                        1.0               1.0                      0.0
#
# [1985 rows x 9 columns]

# %%
df['average_accuracy'].value_counts()
# Out:
# 1.000000    1539
# 0.000000     175
# 0.500000      52
# 0.666667      12
# 0.333333       3
# Name: average_accuracy, dtype: int64

# %%
df = df[['question_number', 'average_accuracy', 'average_appropriateness', 'average_solvability']]
def accuracy(df):
    if df['average_accuracy']>.5:
        return 1
    if df['average_accuracy']==np.nan:
        return np.nan
    if df['average_accuracy']<=0.5:
        return 0
def solvability(df):
    if df['average_solvability']>.5:
        return 1
    else:
        return 0
def appropriateness(df):
    if df['average_appropriateness']>.5:
        return 1
    else:
        return 0
df['solvability']=df.apply(solvability, axis=1)
df['appropriateness']=df.apply(appropriateness, axis=1)
df['accuracy']=df.apply(accuracy, axis=1)
df = df[['question_number', 'accuracy', 'solvability', 'appropriateness']]
df = df.drop_duplicates()
df
# Out:
# <ipython-input-18-ce79b95c83ac>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['solvability']=df.apply(solvability, axis=1)
# <ipython-input-18-ce79b95c83ac>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['appropriateness']=df.apply(appropriateness, axis=1)
# <ipython-input-18-ce79b95c83ac>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['accuracy']=df.apply(accuracy, axis=1)
#      question_number  accuracy  solvability  appropriateness
# 166    question_1521       1.0            1                1
# 167     question_279       0.0            1                0
# 168    question_1266       1.0            1                0
# 169    question_2923       1.0            1                1
# 170     question_414       NaN            0                0
# ...              ...       ...          ...              ...
# 2146    question_913       1.0            1                1
# 2147    question_385       1.0            1                0
# 2148   question_2859       NaN            0                0
# 2149   question_2430       1.0            1                1
# 2150    question_807       1.0            1                0
#
# [1649 rows x 4 columns]

# %% [markdown]
# ## Merge DF with Question Data and Send to CSV

# %%
questions = pd.read_csv('llama_QA_questions.csv')
questions
# Out:
#       Unnamed: 0                                           question  \
# 0            584  4 unicorns ate 24 apples. 3 of the unicorns at...
# 1            562  240 scoops of ice cream were evenly divided in...
# 2           1107  T'Challa is the king of Wakanda. He has 2000 w...
# 3            199  24 cars were in a parking lot. 14 more cars ca...
# 4           1080  A lacrosse team has 24 players. 11 of the play...
# ...          ...                                                ...
# 3231         692  Barbie has 245 1s, 225 5s, 123 10s, and 124 20...
# 3232         862  Thor, the God of Thunder, is 2000 years old. 1...
# 3233         283  Wonder Woman is 6,000 years old. 5,000 years a...
# 3234         237  The mall has 521 parking spots. 128 of the par...
# 3235         133  3000 cookies are baked in an oven. 2/5 of the ...
#
#                                                solution answer          topic  \
# 0     def solution():\n    #4 unicorns ate 24 apples...      0       unicorns
# 1     def solution():\n    #Total scoops of ice crea...    8.0      ice cream
# 2     def solution():\n    #T'Challa has 2000 warrio...   1500  Black Panther
# 3     def solution():\n    #There were 24 cars in th...     31           cars
# 4     def solution():\n    #Total players\n    total...      0       lacrosse
# ...                                                 ...    ...            ...
# 3231  def solution():\n    #Barbie has 245 1s\n    o...   5080         Barbie
# 3232  def solution():\n    #Thor is 2000 years old\n...   2250           Thor
# 3233  def solution():\n    #Wonder Woman is 6,000 ye...   1100   Wonder Woman
# 3234  def solution():\n    #Total parking spots\n   ...    100            NaN
# 3235  def solution():\n    #3000 cookies are baked\n...   3000        cookies
#
#      question_number
# 0         question_0
# 1         question_1
# 2         question_2
# 3         question_3
# 4         question_4
# ...              ...
# 3231   question_3231
# 3232   question_3232
# 3233   question_3233
# 3234   question_3234
# 3235   question_3235
#
# [3236 rows x 6 columns]

# %%
merged = pd.merge(df, questions,
              on = 'question_number',
              how='inner',
              validate='one_to_one', 
              indicator = 'matched')
merged['matched'].value_counts()
# Out:
# both          1649
# left_only        0
# right_only       0
# Name: matched, dtype: int64

# %%
merged = pd.merge(df, questions,
              on = 'question_number',
              how='inner')
merged
# Out:
#      question_number  accuracy  solvability  appropriateness  Unnamed: 0  \
# 0      question_1521       1.0            1                1         633
# 1       question_279       0.0            1                0         403
# 2      question_1266       1.0            1                0          75
# 3      question_2923       1.0            1                1         568
# 4       question_414       NaN            0                0         807
# ...              ...       ...          ...              ...         ...
# 1644    question_913       1.0            1                1         480
# 1645    question_385       1.0            1                0        1233
# 1646   question_2859       NaN            0                0         462
# 1647   question_2430       1.0            1                1         145
# 1648    question_807       1.0            1                0        1274
#
#                                                question  \
# 0     A candy store has 45000 pieces of candy. 10000...
# 1     The 12:05 p.m. train from New York to Boston i...
# 2     Taylor Swift is on a 2-year contract with her ...
# 3     The Beverly Hills Bakery baked 200 loaves of b...
# 4     There are 4 Ninja Turtles. 3 of them are weari...
# ...                                                 ...
# 1644  Thor, the God of Thunder, has 1200 lightning b...
# 1645  Steph Curry, the NBA player, is 6 feet 3 inche...
# 1646  A 220-pound gorilla ate 100 pounds of bananas,...
# 1647  On the first day of the bake sale, 120 cupcake...
# 1648  In the game of Minecraft, 4000 experience poin...
#
#                                                solution                answer  \
# 0     def solution():\n    #The candy store has 4500...                 15000
# 1     def solution():\n    #The 12:05 p.m. train is ...  -0.08333333333333348
# 2     def solution():\n    #Taylor Swift has to prod...    1.4583333333333333
# 3     def solution():\n    #The bakers at the Beverl...                   290
# 4     def solution():\n    #There are 4 Ninja Turtle...                     0
# ...                                                 ...                   ...
# 1644  def solution():\n    #Thor started with 1200 l...                   800
# 1645  def solution():\n    #Steph Curry's height in ...    19099.989686005567
# 1646  def solution():\n    #The gorilla weighed 300 ...                   150
# 1647  def solution():\n    #On the first day, 120 cu...                   600
# 1648  def solution():\n    #Gaige has 3800 experienc...                  -800
#
#               topic
# 0             candy
# 1            trains
# 2      Taylor Swift
# 3               NaN
# 4     Ninja Turtles
# ...             ...
# 1644           Thor
# 1645    Steph Curry
# 1646            NaN
# 1647            NaN
# 1648      Minecraft
#
# [1649 rows x 9 columns]

# %%
merged['text'] = "Question: " + merged['question'] + "\nSolution:\n" + merged['solution'] + "\nAnswer: " + merged['answer']

# %%
print(merged.iloc[0]['text'])
# Out:
# Question: A candy store has 45000 pieces of candy. 10000 of the candies are M&Ms, 20000 are Skittles, and the rest are Starbursts. How many Starbursts are there?
# Solution:
# def solution():
#     #The candy store has 45000 pieces of candy
#     candy_total = 45000
#     #10000 of the candies are M&Ms
#     m_and_ms = 10000
#     #20000 are Skittles
#     skittles = 20000
#     #The rest are Starbursts
#     starbursts = candy_total - m_and_ms - skittles
#     return starbursts
# Answer: 15000

# %%
solvability = merged[['solvability', 'text']]
solvability = solvability.rename({'solvability': 'label'}, axis=1)
solvability.to_csv('data/solvability.csv')
solvability
# Out:
#       label                                               text
# 0         1  Question: A candy store has 45000 pieces of ca...
# 1         1  Question: The 12:05 p.m. train from New York t...
# 2         1  Question: Taylor Swift is on a 2-year contract...
# 3         1  Question: The Beverly Hills Bakery baked 200 l...
# 4         0  Question: There are 4 Ninja Turtles. 3 of them...
# ...     ...                                                ...
# 1644      1  Question: Thor, the God of Thunder, has 1200 l...
# 1645      1  Question: Steph Curry, the NBA player, is 6 fe...
# 1646      0  Question: A 220-pound gorilla ate 100 pounds o...
# 1647      1  Question: On the first day of the bake sale, 1...
# 1648      1  Question: In the game of Minecraft, 4000 exper...
#
# [1649 rows x 2 columns]

# %%
solvability['label'].mean()
# Out:
# 0.8629472407519709

# %%
accuracy = merged[['accuracy', 'text']]
accuracy = accuracy[accuracy['accuracy'].notna()]
accuracy = accuracy.rename({'accuracy': 'label'}, axis=1)
accuracy.to_csv('data/accuracy.csv')
accuracy
# Out:
#       label                                               text
# 0       1.0  Question: A candy store has 45000 pieces of ca...
# 1       0.0  Question: The 12:05 p.m. train from New York t...
# 2       1.0  Question: Taylor Swift is on a 2-year contract...
# 3       1.0  Question: The Beverly Hills Bakery baked 200 l...
# 5       0.0  Question: 100 people are on a Fortnite server....
# ...     ...                                                ...
# 1642    1.0  Question: Batman has 2000 Batarangs. He uses 1...
# 1644    1.0  Question: Thor, the God of Thunder, has 1200 l...
# 1645    1.0  Question: Steph Curry, the NBA player, is 6 fe...
# 1647    1.0  Question: On the first day of the bake sale, 1...
# 1648    1.0  Question: In the game of Minecraft, 4000 exper...
#
# [1458 rows x 2 columns]

# %%
accuracy['label'].mean()
# Out:
# 0.8758573388203018

# %%
appropriateness = merged[['appropriateness', 'text']]
appropriateness = appropriateness.rename({'appropriateness': 'label'}, axis = 1)
appropriateness.to_csv('data/appropriateness.csv')
appropriateness
# Out:
#       label                                               text
# 0         1  Question: A candy store has 45000 pieces of ca...
# 1         0  Question: The 12:05 p.m. train from New York t...
# 2         0  Question: Taylor Swift is on a 2-year contract...
# 3         1  Question: The Beverly Hills Bakery baked 200 l...
# 4         0  Question: There are 4 Ninja Turtles. 3 of them...
# ...     ...                                                ...
# 1644      1  Question: Thor, the God of Thunder, has 1200 l...
# 1645      0  Question: Steph Curry, the NBA player, is 6 fe...
# 1646      0  Question: A 220-pound gorilla ate 100 pounds o...
# 1647      1  Question: On the first day of the bake sale, 1...
# 1648      0  Question: In the game of Minecraft, 4000 exper...
#
# [1649 rows x 2 columns]

# %%
appropriateness['label'].mean()
# Out:
# 0.7016373559733171

# %% [markdown]
# ## Explore Notes

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
temp
# Out:
#       classification_id                           user_name    user_id  \
# 186           518709509  not-logged-in-a37966e36cc5dda457a0        NaN
# 190           518710516  not-logged-in-00a6e25e48bf5304e5da        NaN
# 204           518734315  not-logged-in-c569a3df9a17a44dfe1b        NaN
# 205           518734316  not-logged-in-c569a3df9a17a44dfe1b        NaN
# 208           518734491  not-logged-in-c569a3df9a17a44dfe1b        NaN
# 212           518734708  not-logged-in-c569a3df9a17a44dfe1b        NaN
# 221           518735055  not-logged-in-c569a3df9a17a44dfe1b        NaN
# 227           518736122                         Raceaturtle  2668246.0
# 236           518736551                         Raceaturtle  2668246.0
# 255           518737528                         Raceaturtle  2668246.0
# 257           518737599                         Raceaturtle  2668246.0
# 277           518738439                         Raceaturtle  2668246.0
# 324           518916599  not-logged-in-aa12a45add155049048e        NaN
# 329           518992865                           kidleader  2668795.0
# 330           518993036                           kidleader  2668795.0
# 332           518993310                           kidleader  2668795.0
# 333           518993922                           kidleader  2668795.0
# 334           518994092                           kidleader  2668795.0
# 335           518994181                           kidleader  2668795.0
# 336           518994344                           kidleader  2668795.0
# 337           518994436                           kidleader  2668795.0
# 338           518994634                           kidleader  2668795.0
# 339           518994879                           kidleader  2668795.0
# 341           518995126                           kidleader  2668795.0
# 343           518995459                           kidleader  2668795.0
# 347           518995772                           kidleader  2668795.0
# 348           518996131                           kidleader  2668795.0
# 350           518996257                           kidleader  2668795.0
# 351           518999373                           kidleader  2668795.0
# 352           518999427                           kidleader  2668795.0
# 367           519019147                         Raceaturtle  2668246.0
# 372           519020146                         Raceaturtle  2668246.0
# 374           519020380                         Raceaturtle  2668246.0
# 375           519020514                         Raceaturtle  2668246.0
# 376           519020601                         Raceaturtle  2668246.0
# 377           519020715                         Raceaturtle  2668246.0
# 379           519020948                         Raceaturtle  2668246.0
# 381           519021064                         Raceaturtle  2668246.0
# 407           519054453  not-logged-in-f660d68557d025e537c0        NaN
# 408           519054986  not-logged-in-5003422c879915ca6375        NaN
# 411           519056426  not-logged-in-6493ecc5f19bb3afc336        NaN
# 412           519056508  not-logged-in-6493ecc5f19bb3afc336        NaN
# 414           519056773  not-logged-in-4ef2270edf82e8f04289        NaN
# 416           519057032  not-logged-in-2674bf5585daa7a56d65        NaN
# 417           519057282  not-logged-in-f7a1f61a72f3d67a109f        NaN
# 420           519058162  not-logged-in-7abcac31ddda33461caf        NaN
# 428           519059250                         Raceaturtle  2668246.0
# 444           519060868                         Raceaturtle  2668246.0
# 453           519061427  not-logged-in-768283b3eb60ffd348ad        NaN
# 458           519061699  not-logged-in-e73d7fadbde21f8492bb        NaN
# 466           519061989  not-logged-in-8bd59cbb7dcf4dc8270a        NaN
# 468           519062097                         Raceaturtle  2668246.0
# 472           519062281  not-logged-in-c84cc594c0e37b6e9d19        NaN
# 474           519062373                         Raceaturtle  2668246.0
# 484           519062880                         Raceaturtle  2668246.0
# 491           519063176  not-logged-in-f7a1f61a72f3d67a109f        NaN
# 495           519063321  not-logged-in-f7a1f61a72f3d67a109f        NaN
# 499           519063486  not-logged-in-b7d007f3802fbbd873e9        NaN
# 1544  2023-11-03 11:13:52 UTC            NaN     NaN
# 1839  2023-11-04 10:44:50 UTC            NaN     NaN
# 1840  2023-11-04 10:45:52 UTC            NaN     NaN
# 1845  2023-11-04 10:49:04 UTC            NaN     NaN
# 1846  2023-11-04 10:50:24 UTC            NaN     NaN
# 1848  2023-11-04 10:53:52 UTC            NaN     NaN
# 1849  2023-11-04 10:55:31 UTC            NaN     NaN
# 1854  2023-11-04 11:00:34 UTC            NaN     NaN
# 1862  2023-11-04 11:08:15 UTC            NaN     NaN
# 1865  2023-11-04 11:11:08 UTC            NaN     NaN
# 1866  2023-11-04 11:14:35 UTC            NaN     NaN
# 1985  2023-11-04 23:11:47 UTC            NaN     NaN
# 1988  2023-11-04 23:13:43 UTC            NaN     NaN
# 1997  2023-11-04 23:19:11 UTC            NaN     NaN
# 1999  2023-11-04 23:22:32 UTC            NaN     NaN
# 2004  2023-11-04 23:26:29 UTC            NaN     NaN
# 2005  2023-11-04 23:27:45 UTC            NaN     NaN
# 2125  2023-11-05 10:44:39 UTC            NaN     NaN
# 2127  2023-11-05 10:47:24 UTC            NaN     NaN
# 2128  2023-11-05 10:50:23 UTC            NaN     NaN
# 2130  2023-11-05 10:54:20 UTC            NaN     NaN
# 2134  2023-11-05 10:59:03 UTC            NaN     NaN
# 2136  2023-11-05 11:00:10 UTC            NaN     NaN
#
#                                                metadata  \
# 186   {"source":"api","session":"cab4af948923ae20b20...
# 190   {"source":"api","session":"cab4af948923ae20b20...
# 204   {"source":"api","session":"cab4af948923ae20b20...
# 205   {"source":"api","session":"cab4af948923ae20b20...
# 208   {"source":"api","session":"cab4af948923ae20b20...
# 212   {"source":"api","session":"cab4af948923ae20b20...
# 221   {"source":"api","session":"cab4af948923ae20b20...
# 227   {"source":"api","session":"cab4af948923ae20b20...
# 236   {"source":"api","session":"cab4af948923ae20b20...
# 255   {"source":"api","session":"cab4af948923ae20b20...
# 257   {"source":"api","session":"cab4af948923ae20b20...
# 277   {"source":"api","session":"cab4af948923ae20b20...
# 324   {"source":"api","session":"0481b58dc41a1711cd9...
# 329   {"source":"api","session":"4c190828772a101a1fe...
# 330   {"source":"api","session":"4c190828772a101a1fe...
# 332   {"source":"api","session":"4c190828772a101a1fe...
# 333   {"source":"api","session":"4c190828772a101a1fe...
# 334   {"source":"api","session":"4c190828772a101a1fe...
# 335   {"source":"api","session":"4c190828772a101a1fe...
# 336   {"source":"api","session":"4c190828772a101a1fe...
# 337   {"source":"api","session":"4c190828772a101a1fe...
# 338   {"source":"api","session":"4c190828772a101a1fe...
# 339   {"source":"api","session":"4c190828772a101a1fe...
# 341   {"source":"api","session":"4c190828772a101a1fe...
# 343   {"source":"api","session":"4c190828772a101a1fe...
# 347   {"source":"api","session":"4c190828772a101a1fe...
# 348   {"source":"api","session":"4c190828772a101a1fe...
# 350   {"source":"api","session":"4c190828772a101a1fe...
# 351   {"source":"api","session":"8b372c407f5df39ebd4...
# 352   {"source":"api","session":"8b372c407f5df39ebd4...
# 367   {"source":"api","session":"b797f2b4983cc100354...
# 372   {"source":"api","session":"b797f2b4983cc100354...
# 374   {"source":"api","session":"b797f2b4983cc100354...
# 375   {"source":"api","session":"b797f2b4983cc100354...
# 376   {"source":"api","session":"b797f2b4983cc100354...
# 377   {"source":"api","session":"b797f2b4983cc100354...
# 379   {"source":"api","session":"b797f2b4983cc100354...
# 381   {"source":"api","session":"b797f2b4983cc100354...
# 407   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 408   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 411   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 412   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 414   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 416   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 417   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 420   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 428   {"source":"api","session":"81c527171eb5007b165...
# 444   {"source":"api","session":"81c527171eb5007b165...
# 453   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 458   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 466   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 468   {"source":"api","session":"81c527171eb5007b165...
# 472   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 474   {"source":"api","session":"81c527171eb5007b165...
# 484   {"source":"api","session":"81c527171eb5007b165...
# 491   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 495   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 499   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 504   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 550   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 560   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 563   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 569   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 573   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 577   {"source":"api","session":"ef9a60ac86747e8c3ad...
# 607   {"source":"api","session":"9d89d8123affdb229d7...
# 613   {"source":"api","session":"9d89d8123affdb229d7...
# 618   {"source":"api","session":"9d89d8123affdb229d7...
# 619   {"source":"api","session":"9d89d8123affdb229d7...
# 621   {"source":"api","session":"9d89d8123affdb229d7...
# 623   {"source":"api","session":"9d89d8123affdb229d7...
# 624   {"source":"api","session":"9d89d8123affdb229d7...
# 746   {"source":"api","session":"08436f2ab3c67235e65...
# 748   {"source":"api","session":"08436f2ab3c67235e65...
# 751   {"source":"api","session":"08436f2ab3c67235e65...
# 752   {"source":"api","session":"08436f2ab3c67235e65...
# 754   {"source":"api","session":"08436f2ab3c67235e65...
# 756   {"source":"api","session":"08436f2ab3c67235e65...
# 783   {"source":"api","session":"fa4e6ea375080b25407...
# 785   {"source":"api","session":"fa4e6ea375080b25407...
# 788   {"source":"api","session":"fa4e6ea375080b25407...
# 826   {"source":"api","session":"14a1eaa0de6a498e3c7...
# 853   {"source":"api","session":"bd8ef15afdb02f4728f...
# 859   {"source":"api","session":"bd8ef15afdb02f4728f...
# 914   {"source":"api","session":"98cd106cfd0126bc2e7...
# 918   {"source":"api","session":"98cd106cfd0126bc2e7...
# 925   {"source":"api","session":"98cd106cfd0126bc2e7...
# 926   {"source":"api","session":"98cd106cfd0126bc2e7...
# 927   {"source":"api","session":"98cd106cfd0126bc2e7...
# 932   {"source":"api","session":"98cd106cfd0126bc2e7...
# 935   {"source":"api","session":"98cd106cfd0126bc2e7...
# 937   {"source":"api","session":"98cd106cfd0126bc2e7...
# 938   {"source":"api","session":"98cd106cfd0126bc2e7...
# 939   {"source":"api","session":"98cd106cfd0126bc2e7...
# 940   {"source":"api","session":"98cd106cfd0126bc2e7...
# 944   {"source":"api","session":"ad33f496c6c177b5b4e...
# 950   {"source":"api","session":"daaa0531788e528980c...
# 954   {"source":"api","session":"daaa0531788e528980c...
# 1314  {"source":"api","session":"a14453d366ba5b6de32...
# 1326  {"source":"api","session":"a14453d366ba5b6de32...
# 1334  {"source":"api","session":"a14453d366ba5b6de32...
# 1355  {"source":"api","session":"bd5541a5f58ddad37cf...
# 1368  {"source":"api","session":"bd5541a5f58ddad37cf...
# 1388  {"source":"api","session":"9283b4d4acec4426096...
# 1390  {"source":"api","session":"9283b4d4acec4426096...
# 1391  {"source":"api","session":"9283b4d4acec4426096...
# 1396  {"source":"api","session":"9283b4d4acec4426096...
# 1397  {"source":"api","session":"9283b4d4acec4426096...
# 1399  {"source":"api","session":"9283b4d4acec4426096...
# 1404  {"source":"api","session":"9283b4d4acec4426096...
# 1408  {"source":"api","session":"9283b4d4acec4426096...
# 1409  {"source":"api","session":"9283b4d4acec4426096...
# 1412  {"source":"api","session":"9283b4d4acec4426096...
# 1415  {"source":"api","session":"9283b4d4acec4426096...
# 1418  {"source":"api","session":"9283b4d4acec4426096...
# 1511  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1512  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1515  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1517  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1518  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1519  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1520  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1528  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1533  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1537  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1538  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1539  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1540  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1541  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1542  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1544  {"source":"api","session":"af48d65a23c4bb8c0f4...
# 1839  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1840  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1845  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1846  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1848  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1849  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1854  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1862  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1865  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1866  {"source":"api","session":"c9ad08a1d9674ce9315...
# 1985  {"source":"api","session":"00518e0e87fcf3831e5...
# 1988  {"source":"api","session":"00518e0e87fcf3831e5...
# 1997  {"source":"api","session":"00518e0e87fcf3831e5...
# 1999  {"source":"api","session":"00518e0e87fcf3831e5...
# 2004  {"source":"api","session":"00518e0e87fcf3831e5...
# 2005  {"source":"api","session":"00518e0e87fcf3831e5...
# 2125  {"source":"api","session":"7501932d62eb7243f25...
# 2127  {"source":"api","session":"7501932d62eb7243f25...
# 2128  {"source":"api","session":"7501932d62eb7243f25...
# 2130  {"source":"api","session":"7501932d62eb7243f25...
# 2134  {"source":"api","session":"7501932d62eb7243f25...
# 2136  {"source":"api","session":"7501932d62eb7243f25...
#
#                                             annotations  \
# 186   [{"task":"T0","task_label":"Is this question s...
# 190   [{"task":"T0","task_label":"Is this question s...
# 204   [{"task":"T0","task_label":"Is this question s...
# 205   [{"task":"T0","task_label":"Is this question s...
# 208   [{"task":"T0","task_label":"Is this question s...
# 212   [{"task":"T0","task_label":"Is this question s...
# 221   [{"task":"T0","task_label":"Is this question s...
# 227   [{"task":"T0","task_label":"Is this question s...
# 236   [{"task":"T0","task_label":"Is this question s...
# 255   [{"task":"T0","task_label":"Is this question s...
# 257   [{"task":"T0","task_label":"Is this question s...
# 277   [{"task":"T0","task_label":"Is this question s...
# 324   [{"task":"T0","task_label":"Is this question s...
# 329   [{"task":"T0","task_label":"Is this question s...
# 330   [{"task":"T0","task_label":"Is this question s...
# 332   [{"task":"T0","task_label":"Is this question s...
# 333   [{"task":"T0","task_label":"Is this question s...
# 334   [{"task":"T0","task_label":"Is this question s...
# 335   [{"task":"T0","task_label":"Is this question s...
# 336   [{"task":"T0","task_label":"Is this question s...
# 337   [{"task":"T0","task_label":"Is this question s...
# 338   [{"task":"T0","task_label":"Is this question s...
# 339   [{"task":"T0","task_label":"Is this question s...
# 341   [{"task":"T0","task_label":"Is this question s...
# 343   [{"task":"T0","task_label":"Is this question s...
# 347   [{"task":"T0","task_label":"Is this question s...
# 348   [{"task":"T0","task_label":"Is this question s...
# 350   [{"task":"T0","task_label":"Is this question s...
# 351   [{"task":"T0","task_label":"Is this question s...
# 352   [{"task":"T0","task_label":"Is this question s...
# 367   [{"task":"T0","task_label":"Is this question s...
# 372   [{"task":"T0","task_label":"Is this question s...
# 374   [{"task":"T0","task_label":"Is this question s...
# 375   [{"task":"T0","task_label":"Is this question s...
# 376   [{"task":"T0","task_label":"Is this question s...
# 377   [{"task":"T0","task_label":"Is this question s...
# 379   [{"task":"T0","task_label":"Is this question s...
# 381   [{"task":"T0","task_label":"Is this question s...
# 407   [{"task":"T0","task_label":"Is this question s...
# 408   [{"task":"T0","task_label":"Is this question s...
# 411   [{"task":"T0","task_label":"Is this question s...
# 412   [{"task":"T0","task_label":"Is this question s...
# 414   [{"task":"T0","task_label":"Is this question s...
# 416   [{"task":"T0","task_label":"Is this question s...
# 417   [{"task":"T0","task_label":"Is this question s...
# 420   [{"task":"T0","task_label":"Is this question s...
# 428   [{"task":"T0","task_label":"Is this question s...
# 444   [{"task":"T0","task_label":"Is this question s...
# 453   [{"task":"T0","task_label":"Is this question s...
# 458   [{"task":"T0","task_label":"Is this question s...
# 466   [{"task":"T0","task_label":"Is this question s...
# 468   [{"task":"T0","task_label":"Is this question s...
# 472   [{"task":"T0","task_label":"Is this question s...
# 474   [{"task":"T0","task_label":"Is this question s...
# 484   [{"task":"T0","task_label":"Is this question s...
# 491   [{"task":"T0","task_label":"Is this question s...
# 495   [{"task":"T0","task_label":"Is this question s...
# 499   [{"task":"T0","task_label":"Is this question s...
# 504   [{"task":"T0","task_label":"Is this question s...
# 550   [{"task":"T0","task_label":"Is this question s...
# 560   [{"task":"T0","task_label":"Is this question s...
# 563   [{"task":"T0","task_label":"Is this question s...
# 569   [{"task":"T0","task_label":"Is this question s...
# 573   [{"task":"T0","task_label":"Is this question s...
# 577   [{"task":"T0","task_label":"Is this question s...
# 607   [{"task":"T0","task_label":"Is this question s...
# 613   [{"task":"T0","task_label":"Is this question s...
# 618   [{"task":"T0","task_label":"Is this question s...
# 619   [{"task":"T0","task_label":"Is this question s...
# 621   [{"task":"T0","task_label":"Is this question s...
# 623   [{"task":"T0","task_label":"Is this question s...
# 624   [{"task":"T0","task_label":"Is this question s...
# 746   [{"task":"T0","task_label":"Is this question s...
# 748   [{"task":"T0","task_label":"Is this question s...
# 751   [{"task":"T0","task_label":"Is this question s...
# 752   [{"task":"T0","task_label":"Is this question s...
# 754   [{"task":"T0","task_label":"Is this question s...
# 756   [{"task":"T0","task_label":"Is this question s...
# 783   [{"task":"T0","task_label":"Is this question s...
# 785   [{"task":"T0","task_label":"Is this question s...
# 788   [{"task":"T0","task_label":"Is this question s...
# 826   [{"task":"T0","task_label":"Is this question s...
# 853   [{"task":"T0","task_label":"Is this question s...
# 859   [{"task":"T0","task_label":"Is this question s...
# 914   [{"task":"T0","task_label":"Is this question s...
# 918   [{"task":"T0","task_label":"Is this question s...
# 925   [{"task":"T0","task_label":"Is this question s...
# 926   [{"task":"T0","task_label":"Is this question s...
# 927   [{"task":"T0","task_label":"Is this question s...
# 932   [{"task":"T0","task_label":"Is this question s...
# 935   [{"task":"T0","task_label":"Is this question s...
# 937   [{"task":"T0","task_label":"Is this question s...
# 938   [{"task":"T0","task_label":"Is this question s...
# 939   [{"task":"T0","task_label":"Is this question s...
# 940   [{"task":"T0","task_label":"Is this question s...
# 944   [{"task":"T0","task_label":"Is this question s...
# 950   [{"task":"T0","task_label":"Is this question s...
# 954   [{"task":"T0","task_label":"Is this question s...
# 1314  [{"task":"T0","task_label":"Is this question s...
# 1326  [{"task":"T0","task_label":"Is this question s...
# 1334  [{"task":"T0","task_label":"Is this question s...
# 1355  [{"task":"T0","task_label":"Is this question s...
# 1368  [{"task":"T0","task_label":"Is this question s...
# 1388  [{"task":"T0","task_label":"Is this question s...
# 1390  [{"task":"T0","task_label":"Is this question s...
# 1391  [{"task":"T0","task_label":"Is this question s...
# 1396  [{"task":"T0","task_label":"Is this question s...
# ...
# 607           No  No: This question contains distracting typos o...       NA
# 613          Yes  Yes: This question is understandable, appropri...      Yes
# 618          Yes  Yes: This question is understandable, appropri...       No
# 619           No  No: This question is strange, confusing, conta...       NA
# 621          Yes  Yes: This question is understandable, appropri...       No
# 623           No  No: This question is strange, confusing, conta...       NA
# 624          Yes  Yes: This question is understandable, appropri...      Yes
# 746          Yes  Yes: This question is understandable, appropri...      Yes
# 748          Yes  No: This question is strange, confusing, conta...       No
# 751          Yes  Yes: This question is understandable, appropri...       No
# 752          Yes  Yes: This question is understandable, appropri...      Yes
# 754          Yes  No: This question is strange, confusing, conta...       No
# 756          Yes  Yes: This question is understandable, appropri...       No
# 783          Yes  No: This question is strange, confusing, conta...      Yes
# 785          Yes  No: This question is strange, confusing, conta...      Yes
# 788          Yes  No: This question is strange, confusing, conta...      Yes
# 826          Yes  Yes: This question is understandable, appropri...       No
# 853          Yes  No: This question is strange, confusing, conta...       No
# 859          Yes  Yes: This question is understandable, appropri...       No
# 914          Yes  Yes: This question is understandable, appropri...      Yes
# 918          Yes  Yes: This question is understandable, appropri...      Yes
# 925          Yes  No: This question is strange, confusing, conta...      Yes
# 926           No  No: This question is strange, confusing, conta...       NA
# 927          Yes  No: This question is strange, confusing, conta...       No
# 932          Yes  No: This question is strange, confusing, conta...      Yes
# 935          Yes  Yes: This question is understandable, appropri...      Yes
# 937          Yes  Yes: This question is understandable, appropri...      Yes
# 938          Yes  Yes: This question is understandable, appropri...      Yes
# 939          Yes  Yes: This question is understandable, appropri...      Yes
# 940          Yes  No: This question is strange, confusing, conta...      Yes
# 944           No  No: This question is strange, confusing, conta...       NA
# 950           No  No: This question is strange, confusing, conta...       NA
# 954          Yes  No: This question is strange, confusing, conta...      Yes
# 1314         Yes  No: This question contains distracting typos o...       No
# 1326         Yes  Yes: This question is understandable, appropri...       No
# 208             This could be seen as a trick question…
# 212   We need to better define that the first number...
# 221                Vaccines may be considered political
# 227   This is a ratio, not a division question. Also...
# 236   Substituted implies the players are replaced s...
# 255                      Not accurate distance or speed
# 257                             Some info is not needed
# 277   Need to differentiate the final type from the ...
# 324                                    No negative m&ms
# 329                           Best for grade 6 or older
# 330   Would be simpler if it stated when 300 unfollo...
# 332   2400 - "at least 1 of the 2" means either/or b...
# 333   Elementary students are accustomed to seeing p...
# 334   How can he make more shots than he attempted? ...
# 335                 Appropriate for grades 3 or younger
# 336   Pattern is for every extra .5 liter, + 30. Ans...
# 337                 Appropriate for grades 4 and older.
# 338   I tried using ratios and the math still wasn't...
# 339   The information is inadequate regarding baking...
# 341   In reality, there could be items on sale if bo...
# 343   Students are taught to never list answers like...
# 347   Grade 8 students and younger haven't yet memor...
# 348   Appropriate for grade 3 or older as long as th...
# 350                 Appropriate for grade 3 or younger.
# 351   It would be helpful if the problem stated that...
# 352                   Appropriate for grade 4 and older
# 367           Plane can’t be over two locations at once
# 372   Here I assume each unicorn eats the specified ...
# 374   Need to clarify all the other windows are in f...
# 375                         The wording is a bit tricky
# 376   Assumes students know high school is 9-12th grade
# 377                       The answer would be negative
# 379                                       Answer is 135
# 381                Assumes black ranger is the last one
# 407   If the Yellow Ranger is 1/4 as powerful as the...
# 408   The question contains conflicting information....
# 411   LLMs have a really hard time with this kind of...
# 412   From the questions I've seen so far, the LLM c...
# 414   It's not super inappropriate, but the question...
# 416   There is no math required to solve this questi...
# 417   The solution uses information about a 2-scoop ...
# 420   This one is phrased a little strangely, but th...
# 428                                          No killing
# 444                     Assumes the driver is not cargo
# 453   The question is confusing because we don't kno...
# 458   Steph Curry has been in the NBA for more than ...
# 466   We don't know how many total players are in th...
# 468                                       A bit unclear
# 472   Ahhhh, 120000 spiders!!! The question is mostl...
# 474                               Wrong unit conversion
# 484                                           “In each”
# 491   The question has extraneous information. Maybe...
# 495                         This question is awesome!!!
# 499   There can't be a negative number of cats in th...
# 504   This is a great format for the question, but t...
# 550                    Contains extraneous information.
# 560                                               Nice.
# 563   I think this question requires the knowledge t...
# 569           result should = percent_of_number / 0.012
# 573                             25 yards is 900 inches.
# 577   The wording is a little ambiguous. It's not cl...
# 607   Student needs to know how many goombas he stomps.
# 613                                calculators allowed?
# 618                                         1200 people
# 619   Student needs to know if the 3 friends each at...
# 621                                                   8
# 623             + 40 or + 312? Wording must be clearer.
# 624   Captain Marvel is female? Check the wording in...
# 746   Many answers include a decimal point. This one...
# 748   In reality, $ contains only 2 decimal places; ...
# 751   22 slices of pizza are left - It is stated in ...
# 752   Is Captain Marvel female? This may distract so...
# 754   Baker baked 100 loaves. It is stated in the fi...
# 756                 Not people but scoops = 1150 scoops
# 783   It can be solved but it is kind of strange how...
# 785   It should say how many points did he score the...
# 788    you can't have -400 people remaining at the mall
# 826   210-25-40 = 145  (Assuming the discount pile i...
# 853                                                  20
# 859                                                  60
# 914   I appreciate that it’s something that matters ...
# 918   Change the first line to … has 22 suits at hom...
# 925   Slightly confusing if pieces are counted twice...
# 926   Unclear what the end is asking for (I would ha...
# 927   Clarify what unity of measurement you want the...
# 932   Confusing. What is a hit point vs damage vs th...
# 935   Soccer teams start 11 players. Usually have no...
# 937   She has 23 singles grand slam titles and an ad...
# 938   Change 500 more to 500 new. More could be more...
# 939   Change general public to neutral spectators. A...
# 940   Need to specify why you mean by left? Based on...
# 944     How do you have 0.5833... of a lacrosse player?
# 950   Fractions, Decimals and Percentages go togethe...
# 954   I'm starting to get lost in wondering what is ...
# 1314                                                150
# 1326                    Need to factor in the home team
# 1334                  There are 2 answers x100 and /100
# 1355                                                3/4
# 1368                              Total skiffles is 144
# 1388  It's a simple division problem: the answer mus...
# 1390                                        150 minutes
# 1391  Still being distracted by Captain Marvel's gen...
# 1396  100% of 300 rushing yards...need to know how m...
# 1397  How can Patrick throw 20% of his 2020 touchdow...
# 1399  How do you know that the first girl and the sh...
# 1404  Each member practices the routine 240 times un...
# 1408  I'm completely distracted by the fact that 3 c...
# 1409  Realistically, this is not a valid question. I...
# 1412  The question doesn't ask about the flavors...o...
# 1415                                 1 punch per enemy?
# 1418  Questions like this presume prior knowledge wh...
# 1511  Butter isn't sold by the bag...maybe use mini ...
# 1512              6'8" = 80 inches x 2.54 cm = 203.2 cm
# 1515  10 because the question says "and". If it said...
# 1517  Key word is "does"...this will trick many stud...
# 1518  In 10 years, Naruto will be 22 years of age, n...
# 1519  The answer according to the wording of the que...
# 1520  Answer = 600 lbs. according to the wording of ...
# 1528        2+5+1 = 8 slices with some type of topping.
# 1533  How do you have 0.5 of a commercial airliner? ...
# 1537  This is a simple time span question. Answer = ...
# 1538  Answer = 34 lbs. of ingredients. 32-12 = 20; 2...
# 1539  13 members are on both (according to the first...
# 1540  Baker needs more than 14.75 ounces of just flo...
# 1541  When the first string is playing; 1 player is ...
# 1542  However, there is inadequate information. What...
# 1544  Be sure to match up the grade level appropriat...
# 1839  The question is about his jumping height. 100x...
# 1840                          1200+1400 does not = 2400
# 1845                        He started with 45 gadgets.
# 1846  Are each of the 3 turtles 180 lbs? OR Does the...
# 1848  100 - 1 squad leader = 99 - 2 healers = 97 pla...
# 1849                            14.4 lbs. and 30 inches
# 1854  Players > then 17 + Players = 17 = 12. Therefo...
# 1862  8x19 = 152; Therefore, sum = 27; the + differe...
# 1865  The student needs to know the range of the num...
# 1866  25=fully pink, 23=fully purple, 12= partially ...
# 1985  $333,333,333.33 Answer should be listed as a m...
# 1988  The first sentence answers the question: (100,...
# 1997                 Other titles? What does this mean?
# 1999                        1000 = 50% loss; 1900 = 90%
# 2004                           1800 = blue or red shirt
# 2005  How do points get subtracted in a basketball g...
# 2125                       20 x 52 = 1040 lbs. per year
# 2127  12:10 + 20 min. = 12:30 pm. 12:30 + 15 min. = ...
# 2128    525 - 110 - 211 - 66 = 138 students in neither.
# 2130  More information is required for the answer to...
# 2134  I'm not familiar enough with Instagram to unde...
# 2136                  I already surveyed this question.
